# %% [markdown]
# # 1. Label the sample pairs

# %%
import py_entitymatching as em
import pandas as pd

# %%
S = em.read_csv_metadata("pairs_sample.csv", key='_id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
S.head()
# Out:
#    _id         ltable_vin         rtable_vin                ltable_name  \
# 0   65  JTHCM1D26G5004827  JTHCM1D26G5004827     2016 Lexus IS 300 Base
# 1  377  WDDZF4KB9HA023218  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 2  378  WDDZF4KB3HA135206  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 3  379  WDDZF4KB7HA213910  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 4  380  WDDZF4KBXHA203839  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
#
#    ltable_year   ltable_maker  ltable_price ltable_seller_phone  \
# 0         2016          Lexus       34800.0      (888) 694-7192
# 1         2017  Mercedes-Benz       56499.0      (888) 821-5863
# 2         2017  Mercedes-Benz       55499.0      (888) 821-6594
# 3         2017  Mercedes-Benz       55443.0      (888) 821-5863
# 4         2017  Mercedes-Benz       55085.0      (888) 821-5863
#
#                  ltable_seller_name  ltable_miles  \
# 0               Jacobson Auto Sales        9312.0
# ...

# %%
G = S.copy(deep=True)

# %%
G['label'] = G['ltable_vin'] == G['rtable_vin']

# %%
G.head()
# Out:
#    _id         ltable_vin         rtable_vin                ltable_name  \
# 0   65  JTHCM1D26G5004827  JTHCM1D26G5004827     2016 Lexus IS 300 Base
# 1  377  WDDZF4KB9HA023218  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 2  378  WDDZF4KB3HA135206  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 3  379  WDDZF4KB7HA213910  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 4  380  WDDZF4KBXHA203839  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
#
#    ltable_year   ltable_maker  ltable_price ltable_seller_phone  \
# 0         2016          Lexus       34800.0      (888) 694-7192
# 1         2017  Mercedes-Benz       56499.0      (888) 821-5863
# 2         2017  Mercedes-Benz       55499.0      (888) 821-6594
# 3         2017  Mercedes-Benz       55443.0      (888) 821-5863
# 4         2017  Mercedes-Benz       55085.0      (888) 821-5863
#
#                  ltable_seller_name  ltable_miles  ...    \
# 0               Jacobson Auto Sales        9312.0  ...
# ...

# %%
G['label'].sum()
# Out:
# 222

# %% [markdown]
# We label the car_pair to 1 for True, 0 for False.

# %%
G['label'] = G['label'].apply(lambda x: 1 if x else 0)

# %%
G.head()
# Out:
#    _id         ltable_vin         rtable_vin                ltable_name  \
# 0   65  JTHCM1D26G5004827  JTHCM1D26G5004827     2016 Lexus IS 300 Base
# 1  377  WDDZF4KB9HA023218  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 2  378  WDDZF4KB3HA135206  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 3  379  WDDZF4KB7HA213910  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
# 4  380  WDDZF4KBXHA203839  WDDZF4KB7HA213910  2017 Mercedes-Benz  E 300
#
#    ltable_year   ltable_maker  ltable_price ltable_seller_phone  \
# 0         2016          Lexus       34800.0      (888) 694-7192
# 1         2017  Mercedes-Benz       56499.0      (888) 821-5863
# 2         2017  Mercedes-Benz       55499.0      (888) 821-6594
# 3         2017  Mercedes-Benz       55443.0      (888) 821-5863
# 4         2017  Mercedes-Benz       55085.0      (888) 821-5863
#
#                  ltable_seller_name  ltable_miles  ...   \
# 0               Jacobson Auto Sales        9312.0  ...
# ...

# %%
G.to_csv('pairs_sample_label.csv', index=False)

# %%
# !ls
# Out:
# block.ipynb             features.ipynb          pairs_sample.csv
# cars_com_clean.csv      label.ipynb             pairs_sample_label.csv
# cars_com_luxury.csv     market_api_clean.csv    read-csv.ipynb
# cars_sample.csv         market_check_luxury.csv sample.ipynb
# down-sampling.ipynb     market_sample.csv
# feature_table.csv       pairs.csv
